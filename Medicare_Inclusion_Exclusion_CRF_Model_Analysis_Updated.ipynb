# %% [markdown]
# # Import Libraries

# %%
# import pandas as pd
import numpy as np
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
import pickle
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from collections import OrderedDict
import gradio as gr
from fuzzywuzzy import fuzz
import re
from collections import Counter
# Out:
# C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Install Dependencies

# %%
# !pip install fuzz
# Out:
# Requirement already satisfied: fuzz in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (0.1.1)

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (from textblob) (3.4.5)
# Requirement already satisfied: six in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (from nltk>=3.1->textblob) (1.15.0)

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (0.18.0)

# %%
# !python -m pip install -U symspellpy
# Out:
# Requirement already up-to-date: symspellpy in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (6.7.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.1 in c:\users\ag95028\appdata\local\conda\conda\envs\myenv\lib\site-packages (from symspellpy) (1.18.0)

# %%
df = pd.read_csv('medicare_train_dataset_BOI_input_manual_v3.csv')

# %%
df.head()
# Out:
#    sentence #                                            pattern benefit_type  \
# 0  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 1  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 2  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 3  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 4  sentence 1  Includes programs such as group exercise, adul...         ADCS
#
#           requirement_text      word  POS         tags
# 0  Adult Day Care Services  Includes  NNS            O
# 1  Adult Day Care Services  programs  NNS            O
# 2  Adult Day Care Services      such   JJ            O
# 3  Adult Day Care Services        as   IN            O
# 4  Adult Day Care Services     group   NN  B_INCLUSION

# %% [markdown]
# # Handle Missing Values

# %%
df = df.fillna(method='ffill')

# %%
df['sentence #'].nunique(), df.word.nunique(), df["tags"].nunique()
# Out:
# (250, 1677, 8)

# %%
df.groupby('tags').size().reset_index(name='counts')
# Out:
#           tags  counts
# 0  B_EXCLUSION      92
# 1  B_INCLUSION     391
# 2  I_EXCLUSION     238
# 3  I_INCLUSION     869
# 4            O    4874
# 5  U_EXCLUSION      31
# 6  U_INCLUSION     121
# 7  i_EXCLUSION       6

# %%
X = df.drop('tags', axis=1)
X.head()
# Out:
#    sentence #                                            pattern benefit_type  \
# 0  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 1  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 2  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 3  sentence 1  Includes programs such as group exercise, adul...         ADCS
# 4  sentence 1  Includes programs such as group exercise, adul...         ADCS
#
#           requirement_text      word  POS
# 0  Adult Day Care Services  Includes  NNS
# 1  Adult Day Care Services  programs  NNS
# 2  Adult Day Care Services      such   JJ
# 3  Adult Day Care Services        as   IN
# 4  Adult Day Care Services     group   NN

# %%
X.columns
# Out:
# Index(['sentence #', 'pattern', 'benefit_type', 'requirement_text', 'word',
#        'POS'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
v = DictVectorizer(sparse=False)
X = v.fit_transform(X.to_dict('records'))
X.shape
# Out:
# (6622, 2361)

# %%
y = df["tags"].values

# %%
classes = np.unique(y)

# %%
classes = classes.tolist()
classes
# Out:
# ['B_EXCLUSION',
#  'B_INCLUSION',
#  'I_EXCLUSION',
#  'I_INCLUSION',
#  'O',
#  'U_EXCLUSION',
#  'U_INCLUSION',
#  'i_EXCLUSION']

# %%
X.shape, y.shape
# Out:
# ((6622, 2361), (6622,))

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state=0)

# %%
#X_train.shape, y_train.shape

# %%
new_classes = classes.copy()
new_classes.pop()
new_classes
# Out:
# ['B_EXCLUSION',
#  'B_INCLUSION',
#  'I_EXCLUSION',
#  'I_INCLUSION',
#  'O',
#  'U_EXCLUSION',
#  'U_INCLUSION']

# %% [markdown]
# # Feature Extraction

# %%
class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w,b,r, p, t) for w,b,r, p, t in zip(s['word'].values.tolist(),
                                                           s['benefit_type'].values.tolist(),
                                                           s['requirement_text'].values.tolist(),
                                                           s['POS'].values.tolist(), 
                                                           s['tags'].values.tolist())]
        self.grouped = self.data.groupby('sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]
        
    def get_next(self):
        try: 
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s 
        except:
            return None

# %%
getter = SentenceGetter(df)

# %%
sent = getter.get_next()
print(sent)
# Out:
# None

# %%
sentences = getter.sentences

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]
    #benefit_type = sent[i][1]
    #requirement_text = sent[i][2]
    
    features = {
        'bias': 1.0, 
        'word.lower()': word.lower(), 
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        #'benefit_type':benefit_type,
        #'requirement_text':requirement_text,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features

def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token,benefit_type,requirement_text, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %%
X = [sent2features(s) for s in sentences]
y = [sent2labels(s) for s in sentences]

# %% [markdown]
# # Splitting the data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_test
# Out:
# [[{'bias': 1.0,
#    'word.lower()': 'this',
#    'word[-3:]': 'his',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    'BOS': True,
#    '+1:word.lower()': 'service',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'service',
#    'word[-3:]': 'ice',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'this',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'usually',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'usually',
#    'word[-3:]': 'lly',
#    'word[-2:]': 'ly',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'service',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'includes',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'includes',
#    'word[-3:]': 'des',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'usually',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'private',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'private',
#    'word[-3:]': 'ate',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'includes',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'quarters',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'quarters',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'private',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'meals',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'meals',
#    'word[-3:]': 'als',
#    'word[-2:]': 'ls',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'quarters',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'personal',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'personal',
#    'word[-3:]': 'nal',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'meals',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'assistance',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'assistance',
#    'word[-3:]': 'nce',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'personal',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'housekeeping',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'housekeeping',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'assistance',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'aid',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'aid',
#    'word[-3:]': 'aid',
#    'word[-2:]': 'id',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'housekeeping',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'monitoring',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'monitoring',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'aid',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'monitoring',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'medications',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'medications',
#    'word[-3:]': 'ons',
#    'word[-2:]': 'ns',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'and',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'and',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'medications',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': "nurses'",
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': "nurses'",
#    'word[-3:]': "es'",
#    'word[-2:]': "s'",
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': 'and',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    '+1:word.lower()': 'visits',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'LARC',
#    '+1:postag[:2]': 'LA'},
#   {'bias': 1.0,
#    'word.lower()': 'visits',
#    'word[-3:]': 'its',
#    'word[-2:]': 'ts',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'LARC',
#    'postag[:2]': 'LA',
#    '-1:word.lower()': "nurses'",
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'LARC',
#    '-1:postag[:2]': 'LA',
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word.lower()': '2)',
#    'word[-3:]': '2)',
#    'word[-2:]': '2)',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    'BOS': True,
#    '+1:word.lower()': 'chiropractic',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'chiropractic',
#    'word[-3:]': 'tic',
#    'word[-2:]': 'ic',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': '2)',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'maintenance',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'maintenance',
#    'word[-3:]': 'nce',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'chiropractic',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'therapy',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'therapy',
#    'word[-3:]': 'apy',
#    'word[-2:]': 'py',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'maintenance',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'is',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'is',
#    'word[-3:]': 'is',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'therapy',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'not',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'not',
#    'word[-3:]': 'not',
#    'word[-2:]': 'ot',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'is',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'considered',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'considered',
#    'word[-3:]': 'red',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'not',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'considered',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'be',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'be',
#    'word[-3:]': 'be',
#    'word[-2:]': 'be',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'medically',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'medically',
#    'word[-3:]': 'lly',
#    'word[-2:]': 'ly',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'be',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'reasonable',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'reasonable',
#    'word[-3:]': 'ble',
#    'word[-2:]': 'le',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'medically',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'or',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'or',
#    'word[-3:]': 'or',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'reasonable',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'necessary',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'necessary',
#    'word[-3:]': 'ary',
#    'word[-2:]': 'ry',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'or',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'and',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'and',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'necessary',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'is',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'is',
#    'word[-3:]': 'is',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'and',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'therefore',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'therefore',
#    'word[-3:]': 'ore',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'is',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'not',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'not',
#    'word[-3:]': 'not',
#    'word[-2:]': 'ot',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'therefore',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    '+1:word.lower()': 'covered',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'CHIR',
#    '+1:postag[:2]': 'CH'},
#   {'bias': 1.0,
#    'word.lower()': 'covered',
#    'word[-3:]': 'red',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'CHIR',
#    'postag[:2]': 'CH',
#    '-1:word.lower()': 'not',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'CHIR',
#    '-1:postag[:2]': 'CH',
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word.lower()': '-',
#    'word[-3:]': '-',
#    'word[-2:]': '-',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    'BOS': True,
#    '+1:word.lower()': 'emergency',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'emergency',
#    'word[-3:]': 'ncy',
#    'word[-2:]': 'cy',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': '-',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'transportation',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'transportation',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'emergency',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'ambulance',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'ambulance',
#    'word[-3:]': 'nce',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'transportation',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'services',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'services',
#    'word[-3:]': 'ces',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'ambulance',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'include',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'include',
#    'word[-3:]': 'ude',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'services',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'fixed',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'fixed',
#    'word[-3:]': 'xed',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'include',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'wing',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'wing',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'fixed',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'rotary',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'rotary',
#    'word[-3:]': 'ary',
#    'word[-2:]': 'ry',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'wing',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'wing',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'wing',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'rotary',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'and',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'and',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'wing',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'ground',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'ground',
#    'word[-3:]': 'und',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'and',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'ambulance',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'ambulance',
#    'word[-3:]': 'nce',
#    'word[-2:]': 'ce',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'ground',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'services',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'services',
#    'word[-3:]': 'ces',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'ambulance',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'services',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'nearest',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'nearest',
#    'word[-3:]': 'est',
#    'word[-2:]': 'st',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'appropriate',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'appropriate',
#    'word[-3:]': 'ate',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'nearest',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'facility',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'facility',
#    'word[-3:]': 'ity',
#    'word[-2:]': 'ty',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'appropriate',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'that',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'that',
#    'word[-3:]': 'hat',
#    'word[-2:]': 'at',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'facility',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'can',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'can',
#    'word[-3:]': 'can',
#    'word[-2:]': 'an',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'that',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'provide',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'provide',
#    'word[-3:]': 'ide',
#    'word[-2:]': 'de',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'can',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'care',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'care',
#    'word[-3:]': 'are',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'provide',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'if',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'if',
#    'word[-3:]': 'if',
#    'word[-2:]': 'if',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'care',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'they',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'they',
#    'word[-3:]': 'hey',
#    'word[-2:]': 'ey',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'if',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'are',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'are',
#    'word[-3:]': 'are',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'they',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'furnished',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'furnished',
#    'word[-3:]': 'hed',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'are',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'furnished',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'a',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'a',
#    'word[-3:]': 'a',
#    'word[-2:]': 'a',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'member',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'member',
#    'word[-3:]': 'ber',
#    'word[-2:]': 'er',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'a',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'whose',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'whose',
#    'word[-3:]': 'ose',
#    'word[-2:]': 'se',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'member',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'medical',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'medical',
#    'word[-3:]': 'cal',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'whose',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'condition',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'condition',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'medical',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'is',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'is',
#    'word[-3:]': 'is',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'condition',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'such',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'such',
#    'word[-3:]': 'uch',
#    'word[-2:]': 'ch',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'is',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'that',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'that',
#    'word[-3:]': 'hat',
#    'word[-2:]': 'at',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'such',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'other',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'other',
#    'word[-3:]': 'her',
#    'word[-2:]': 'er',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'that',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'means',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'means',
#    'word[-3:]': 'ans',
#    'word[-2:]': 'ns',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'other',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'of',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'of',
#    'word[-3:]': 'of',
#    'word[-2:]': 'of',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'means',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'transportation',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'transportation',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'of',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'could',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'could',
#    'word[-3:]': 'uld',
#    'word[-2:]': 'ld',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'transportation',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'endanger',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'endanger',
#    'word[-3:]': 'ger',
#    'word[-2:]': 'er',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'could',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'endanger',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': "member's",
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': "member's",
#    'word[-3:]': "r's",
#    'word[-2:]': "'s",
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    '+1:word.lower()': 'health',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'TRNS',
#    '+1:postag[:2]': 'TR'},
#   {'bias': 1.0,
#    'word.lower()': 'health',
#    'word[-3:]': 'lth',
#    'word[-2:]': 'th',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'TRNS',
#    'postag[:2]': 'TR',
#    '-1:word.lower()': "member's",
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'TRNS',
#    '-1:postag[:2]': 'TR',
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word.lower()': '3)',
#    'word[-3:]': '3)',
#    'word[-2:]': '3)',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    'BOS': True,
#    '+1:word.lower()': 'minimal',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'minimal',
#    'word[-3:]': 'mal',
#    'word[-2:]': 'al',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': '3)',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'cessation',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'cessation',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'minimal',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'counseling',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'counseling',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'cessation',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'defined',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'defined',
#    'word[-3:]': 'ned',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'counseling',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'as',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'as',
#    'word[-3:]': 'as',
#    'word[-2:]': 'as',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'defined',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'minutes',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'minutes',
#    'word[-3:]': 'tes',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'as',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'or',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'or',
#    'word[-3:]': 'or',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'minutes',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'less',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'less',
#    'word[-3:]': 'ess',
#    'word[-2:]': 'ss',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'or',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'in',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'in',
#    'word[-3:]': 'in',
#    'word[-2:]': 'in',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'less',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'duration',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'duration',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'in',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'is',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'is',
#    'word[-3:]': 'is',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'duration',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'already',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'already',
#    'word[-3:]': 'ady',
#    'word[-2:]': 'dy',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'is',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'considered',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'considered',
#    'word[-3:]': 'red',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'already',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'to',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'to',
#    'word[-3:]': 'to',
#    'word[-2:]': 'to',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'considered',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'be',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'be',
#    'word[-3:]': 'be',
#    'word[-2:]': 'be',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'to',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'SMCS',
#    '-1:postag[:2]': 'SM',
#    '+1:word.lower()': 'covered',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'SMCS',
#    '+1:postag[:2]': 'SM'},
#   {'bias': 1.0,
#    'word.lower()': 'covered',
#    'word[-3:]': 'red',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'SMCS',
#    'postag[:2]': 'SM',
#    '-1:word.lower()': 'be',
#    '-1:word.istitle()': False,
# ...
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    'BOS': True,
#    '+1:word.lower()': 'medicare',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'medicare',
#    'word[-3:]': 'are',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': '28)',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'diabetes',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'diabetes',
#    'word[-3:]': 'tes',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'medicare',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'prevention',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'prevention',
#    'word[-3:]': 'ion',
#    'word[-2:]': 'on',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'diabetes',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'program',
#    '+1:word.istitle()': True,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'program',
#    'word[-3:]': 'ram',
#    'word[-2:]': 'am',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'prevention',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'mdpp',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': True,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'mdpp',
#    'word[-3:]': 'DPP',
#    'word[-2:]': 'PP',
#    'word.isupper()': True,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'program',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'services',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'services',
#    'word[-3:]': 'ces',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'mdpp',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': True,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'are',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'are',
#    'word[-3:]': 'are',
#    'word[-2:]': 're',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'services',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'covered',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'covered',
#    'word[-3:]': 'red',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'are',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'for',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'for',
#    'word[-3:]': 'for',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'covered',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'eligible',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'eligible',
#    'word[-3:]': 'ble',
#    'word[-2:]': 'le',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'for',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    '+1:word.lower()': 'members',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'PREV',
#    '+1:postag[:2]': 'PR'},
#   {'bias': 1.0,
#    'word.lower()': 'members',
#    'word[-3:]': 'ers',
#    'word[-2:]': 'rs',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'PREV',
#    'postag[:2]': 'PR',
#    '-1:word.lower()': 'eligible',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'PREV',
#    '-1:postag[:2]': 'PR',
#    'EOS': True}],
#  [{'bias': 1.0,
#    'word.lower()': 'dialysis',
#    'word[-3:]': 'sis',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': True,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    'BOS': True,
#    '+1:word.lower()': 'home',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'home',
#    'word[-3:]': 'ome',
#    'word[-2:]': 'me',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'dialysis',
#    '-1:word.istitle()': True,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'support',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'support',
#    'word[-3:]': 'ort',
#    'word[-2:]': 'rt',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'home',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'services',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'services',
#    'word[-3:]': 'ces',
#    'word[-2:]': 'es',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'support',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'and',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'and',
#    'word[-3:]': 'and',
#    'word[-2:]': 'nd',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'services',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'self',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'self',
#    'word[-3:]': 'elf',
#    'word[-2:]': 'lf',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'and',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': '-',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': '-',
#    'word[-3:]': '-',
#    'word[-2:]': '-',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'self',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'dialysis',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'dialysis',
#    'word[-3:]': 'sis',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': '-',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'training',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'training',
#    'word[-3:]': 'ing',
#    'word[-2:]': 'ng',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'dialysis',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'may',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'may',
#    'word[-3:]': 'may',
#    'word[-2:]': 'ay',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'training',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'be',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'be',
#    'word[-3:]': 'be',
#    'word[-2:]': 'be',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'may',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'included',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'included',
#    'word[-3:]': 'ded',
#    'word[-2:]': 'ed',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'be',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'if',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'if',
#    'word[-3:]': 'if',
#    'word[-2:]': 'if',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'included',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'the',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'the',
#    'word[-3:]': 'the',
#    'word[-2:]': 'he',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'if',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'member',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'member',
#    'word[-3:]': 'ber',
#    'word[-2:]': 'er',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'the',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'is',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'is',
#    'word[-3:]': 'is',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'member',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'a',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'a',
#    'word[-3:]': 'a',
#    'word[-2:]': 'a',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'is',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'candidate',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'candidate',
#    'word[-3:]': 'ate',
#    'word[-2:]': 'te',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'a',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'for',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'for',
#    'word[-3:]': 'for',
#    'word[-2:]': 'or',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'candidate',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'home',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'home',
#    'word[-3:]': 'ome',
#    'word[-2:]': 'me',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'for',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    '+1:word.lower()': 'dialysis',
#    '+1:word.istitle()': False,
#    '+1:word.isupper()': False,
#    '+1:postag': 'ESRD',
#    '+1:postag[:2]': 'ES'},
#   {'bias': 1.0,
#    'word.lower()': 'dialysis',
#    'word[-3:]': 'sis',
#    'word[-2:]': 'is',
#    'word.isupper()': False,
#    'word.istitle()': False,
#    'word.isdigit()': False,
#    'postag': 'ESRD',
#    'postag[:2]': 'ES',
#    '-1:word.lower()': 'home',
#    '-1:word.istitle()': False,
#    '-1:word.isupper()': False,
#    '-1:postag': 'ESRD',
#    '-1:postag[:2]': 'ES',
#    'EOS': True}]]

# %% [markdown]
# # Model Training

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\sklearn\base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.1,
#     keep_tempfiles=None, max_iterations=100)

# %%
filename = 'medicare_ner_inc_exc_model_updated.pkl'
pickle.dump(crf, open(filename, 'wb'))

# %%
#####prediction on test set#####
crf1 = pickle.load(open('medicare_ner_inc_exc_model_updated.pkl', 'rb'))

# %%
mapping_sheet = pd.read_excel("GBD Medicare Benefit Names and Categories - Inclusion Or Exclusions.xlsx")

# %% [markdown]
# # Spell Correction Check

# %%
mapping_sheet['Benefit Name'].values
# Out:
# array(['Abortion Ambulatory Surgical Center',
#        'Abortion Inpatient Professional',
#        'Abortion Observation Room Outpatient Institutional',
#        'Abortion Office Professional - PCP',
#        'Abortion Office Professional - Specialist',
#        'Abortion Surgery Outpatient Institutional',
#        'Abortion Office Professional - Specialist - Designated Care Program',
#        'Acupuncture',
#        'Mental Health - Crisis Intervention/Crisis Stabilization',
#        'Substance Abuse - Crisis Intervention/Crisis Stabilization',
#        'Mental Health - Intensive Outpatient Program (IOP) Institutional',
#        'Substance Abuse - Intensive Outpatient Program (IOP) Institutional',
#        'Mental Health - Inpatient Institutional - Hospital Days ',
#        'Mental Health - Inpatient Professional',
#        'Mental Health - Inpatient Psychiatric Facility - Hospital Days',
#        'Substance Abuse - Inpatient Institutional - Hospital Days ',
#        'Substance Abuse - Inpatient Professional',
#        'Substance Abuse - Inpatient Psychiatric Facility - Hospital Days',
#        'Mental Health - Outpatient Professional',
#        'Substance Abuse - Outpatient Professional', 'Opioid Treatment',
#        'Mental Health - Outpatient Professional - Designated Care Program',
#        'Substance Abuse - Outpatient Professional - Designated Care Program',
#        'Mental Health - Psychiatric Services',
#        'Mental Health - Psychiatric Services - Designated Care Program',
#        'Mental Health - Partial Hospitalization (PHP) Institutional',
#        'Substance Abuse - Partial Hospitalization (PHP) Institutional',
#        'Mental Health - Residential Treatment Centers',
#        'Substance Abuse - Residential Treatment Centers',
#        'Blood Storage And Administration', 'Cardiac Rehabilitation',
#        'Intensive Cardiac Rehabilitation', 'Chemotherapy',
#        'Radiation Therapy Freestanding Facility',
#        'Radiation Therapy Office Professional',
#        'Radiation Therapy Outpatient Institutional',
#        'Chiropractic Services',
#        'Routine Chiropractic Services - Supplemental',
#        'Cosmetic/Reconstructive Surgery Ambulatory Surgical Center',
#        'Cosmetic/Reconstructive Surgery Inpatient Professional',
#        'Cosmetic/Reconstructive Surgery Observation Room Outpatient Institutional',
#        'Cosmetic/Reconstructive Surgery Office Professional - PCP',
#        'Cosmetic/Reconstructive Surgery Office Professional - Specialist',
#        'Cosmetic/Reconstructive Surgery Outpatient Institutional',
#        'Cosmetic/Reconstructive Surgery Office Professional - Specialist - Designated Care Program',
#        'Annual Deductible',
#        'Comprehensive Dental Services - Supplemental', 'Dental Services',
#        'Preventive Dental Services - Supplemental',
#        'Dental Services - Designated Care Program',
#        'Diagnostic Advanced Imaging Freestanding Radiology Facility',
#        'Diagnostic Advanced Imaging Office Professional',
#        'Diagnostic Advanced Imaging Outpatient Institutional',
#        'Diagnostic Laboratory - Hemoglobin A1c Tests',
#        'Diagnostic Laboratory - Spirometry Tests',
#        'Diagnostic Laboratory - Urine Tests',
#        'Diagnostic Laboratory - Fecal Occult Blood Test',
#        'Diagnostic Laboratory - Peripheral Artery Disease Testing',
#        'Diagnostic Laboratory Freestanding Facility',
#        'Diagnostic Laboratory Office Professional',
#        'Diagnostic Laboratory Outpatient Institutional',
#        'Diagnostic Procedures Freestanding Facility',
#        'Diagnostic Procedures Office Professional\nDiagnostic Procedures Office Professional - PCP',
#        'Diagnostic Procedures Outpatient Institutional',
#        'Diagnostic X-ray Freestanding Facility',
#        'Diagnostic X-ray Mobile Unit',
#        'Diagnostic X-ray Office Professional',
#        'Diagnostic X-ray Outpatient Institutional',
#        'Diagnostic Radiological Office Professional',
#        'Diagnostic Radiological Freestanding Facility',
#        'Diagnostic Radiological Outpatient Institutional',
#        'Diabetic Monitoring Supplies', 'Durable Medical Equipment',
#        'Hyaluronic Acids Outpatient Institutional',
#        'Hyaluronic Acids Office Professional',
#        'Hyaluronic Acids Mobile Unit',
#        'Over The Counter Drugs - Supplemental',
#        'Part B Prescription Drugs Freestanding Facility',
#        'Part B Prescription Drugs Office Professional',
#        'Part B Prescription Drugs Outpatient Institutional',
#        'Early Childhood Intervention (ECI) Services',
#        'Enhanced Disease Management', 'Employment Support Services',
#        'Early Periodic Screening, Diagnosis and Treatment (EPSDT) Services',
#        'Emergency Room Visit Outpatient Institutional',
#        'Emergency Room Visit Outpatient Professional',
#        'Dialysis Home Support Services',
#        'Home Dialysis Equipment And Supplies',
#        'Kidney Dialysis Services - End Stage Renal Disease Treatment Facility',
#        'Kidney Dialysis Services - Inpatient Institutional',
#        'Kidney Dialysis Services - Office Professional - PCP',
#        'Kidney Dialysis Services - Out of Area - End Stage Renal Disease Treatment Facility',
#        'Kidney Dialysis Services - Outpatient Institutional',
#        'Kidney Dialysis Services - Freestanding Facility',
#        'Kidney Disease Education Services', 'Self-Dialysis Training',
#        'Diabetes Training', 'Adult Day Care',
#        'Adult Day Care - Elective EE', 'Alternative Medicine',
#        'Alternative Medicine - Elective EE', 'Assistive Devices',
#        'Assistive Devices - Elective EE', 'Health and Fitness Tracker',
#        'Health and Fitness Tracker - Elective EE',
#        'In-Home Support Services',
#        'In-Home Support Services - Elective EE',
#        'Home Delivered Meals - Elective EE',
#        'Medicare Education Outreach and Support',
#        'Medicare Education Outreach and Support  - Elective EE',
#        'Nutrition', 'Nutrition - Elective EE', 'Pest Control',
#        'Pest Control - Elective EE', 'Personal Home Helper',
#        'Personal Home Helper - Elective EE', 'Service Dog Support',
#        'Service Dog Support - Elective EE',
#        'Transportation - Elective EE', 'Clinical Trials',
#        'Family Planning', 'Bariatric Surgery Inpatient Professional',
#        'Bariatric Surgery Office Professional - PCP',
#        'Bariatric Surgery Office Professional - Specialist',
#        'Bariatric Surgery Office Professional - Specialist - Designated Care Program',
#        'Genetic Testing - Diagnostic Laboratory Freestanding Facility',
#        'Genetic Testing - Diagnostic Laboratory Office Professional\nGenetic Testing - Diagnostic Laboratory Outpatient Professional',
#        'Genetic Testing - Diagnostic Procedures Freestanding Facility',
#        'Genetic Testing - Diagnostic Procedures Outpatient Institutional',
#        'Genetic Testing - Diagnostic Procedures Office Professional\nGenetic Testing - Diagnostic Procedures Outpatient Professional',
#        'Genetic Testing - Office Professional - PCP',
#        'Genetic Testing - Office Professional - Specialist',
#        'Genetic Testing - Diagnostic Advanced Imaging Outpatient Institutional',
#        'Genetic Testing - Office Professional - Specialist - Designated Care Program',
#        'Transgender Services', 'Guest Accommodations',
#        'Physician Services - Advance Care Planning ',
#        'Physician Services - Chiropractic Service',
#        'Physician Services - Hearing Exam',
#        'Physician Services - Inpatient Professional',
#        'Physician Services - Medication Reconciliation Service',
#        'Physician Services - Mental Health - Outpatient Professional',
#        'Physician Services - Non Routine Podiatry Visits',
#        'Physician Services - Office Professional - PCP',
#        'Physician Services - Office Professional - Specialist',
#        'Physician Services - Outpatient Professional',
#        'Physician Services - Preventive Care Services',
#        'Physician Services - Retail Health Clinics',
#        'Physician Services - Routine Podiatry Visits',
#        'Physician Services - Substance Abuse - Outpatient Professional',
#        'Physician Services - Telehealth Visits',
#        'Physician Services - Urgent Care Outpatient Institutional',
#        'Physician Services - Urgent Care Outpatient Professional',
#        'Physician Services - Routine Podiatry Visits - Designated Care Program',
#        'Physician Services - Mental Health - Outpatient Professional - Designated Care Program',
#        'Physician Services - Psychiatric Services',
#        'Physician Services - Psychiatric Services - Designated Care Program',
#        'Physician Services - Office Professional - Specialist - Designated Care Program',
#        'Hearing Aid - Supplemental',
#        'Hearing Aid Fitting/Evaluation- Supplemental', 'Hearing Exam',
#        'Routine Hearing Exam - Supplemental', 'Health Homes',
#        'Home Health Care', 'Medicare Hospice Services',
#        'Hospice Consultation Office Professional - PCP',
#        'Hospice Consultation Office Professional - Specialist',
#        'Hospice Consultation Office Professional - Specialist - Designated Care Program',
#        'Healthy Start Program', 'Flu Shot', 'Hepatitis B Shot',
#        'Other Immunizations Freestanding Facility',
#        'Other Immunizations Office Professional',
#        'Other Immunizations Outpatient Institutional',
#        'Pneumococcal Shot',
#        'Infertility Services - Diagnostic Laboratory Freestanding Facility',
#        'Infertility Services - Diagnostic Laboratory Office Professional',
#        'Infertility Services - Diagnostic Procedures Freestanding Facility',
#        'Infertility Services - Diagnostic Procedures Outpatient Institutional',
#        'Infertility Services - Diagnostic Procedures Office Professional',
#        'Infertility Services - Office Professional - PCP',
#        'Infertility Services - Office Professional - Specialist',
#        'Infertility Services - Diagnostic Advanced Imaging Outpatient Institutional',
#        'Infertility Services - Office Professional - Specialist - Designated Care Program',
#        'Inpatient Institutional - Hospital Days ',
#        'Inpatient Professional', 'Adult Companion Services',
#        'Day Care Services', 'Adult Foster Care',
#        'Assisted Living/Residential Care', 'Attendant Care/Personal Care',
#        'Community Transition Services ', 'Financial Management',
#        'Family Training', 'Habilitation', 'Home Delivered Meals',
#        'Home Environment Evaluation', 'Homemaker Services',
#        'Home and Vehicle Modifications', 'Nursing Home/Facility',
#        'Pest Control\xa0', 'Support Consultation', 'Chore Services',
#        'Medical Supplies', 'Out-of-Pocket Annual Maximum',
#        'Nurse HelpLine',
#        'Out of Area/Out of Country Emergency Care Outpatient Institutional',
#        'Out of Area/Out of Country Emergency Care Outpatient Professional',
#        'Out of Area/Out of Country Urgent Care Outpatient Institutional',
#        'Out of Area/Out of Country Urgent Care Outpatient Professional',
#        'Preventive Dental Services - Optional Preventive Dental',
#        'Other Dental Services - Optional Dental',
#        'Preventive Dental Services - Optional Dental',
#        'Restorative Dental Services - Optional Dental',
#        'Eyewear - Optional Vision',
#        'Other Dental Services - Optional Enhanced Dental',
#        'Preventive Dental Services - Optional Enhanced Dental',
#        'Restorative Dental Services - Optional Enhanced Dental',
#        'Eyewear - Optional Enhanced Vision',
#        'RNHCI Inpatient Institutional - Hospital Days',
#        'RNHCI Intermittent Nursing Visits - Home',
#        'RNHCI Non-Medical DME - Home',
#        'Colorectal Surgery Ambulatory Surgical Center',
#        'Surgery Ambulatory Surgical Center',
#        'Colorectal Surgery Outpatient Institutional',
#        'Observation Room Outpatient Institutional',
#        'Surgery Outpatient Institutional',
#        'Hyperbaric Oxygen Therapy Outpatient Institutional',
#        'Part B Excess Charges', 'Personal Emergency Response System',
#        'Non Routine Podiatry Visits', 'Routine Podiatry Visits',
#        'Routine Podiatry Visits - Supplemental',
#        'Non Routine Podiatry Visits - Designated Care Program',
#        'Routine Podiatry Visits - Designated Care Program',
#        'Routine Podiatry Visits - Supplemental - Designated Care Program',
#        'Private Duty Nursing', 'Abdominal Aortic Aneurysm Screening',
#        'Alcohol Misuse Screening ',
#        'Annual Routine Physical Exam - Supplemental',
#        'Annual Wellness Visit', 'Bone Mass Measurement',
#        'Breast Cancer Screening',
#        'Cardiovascular Disease Risk Reduction Visit',
#        'Cardiovascular Disease Screenings',
#        'Cervical And Vaginal Cancer Screening',
#        'Colorectal Cancer Screenings', 'Depression Screening',
#        'Diabetes Screening', 'Diabetes Self-Management Training',
#        'Glaucoma Screening', 'Hepatitis C Screening', 'HIV Screening',
#        'Immunizations', 'Lung Cancer Screening',
#        'Medical Nutrition Therapy Services',
#        'Medicare Diabetes Prevention Program (MDPP)',
#        'Obesity Screenings And Counseling', 'Prostate Cancer Screenings ',
#        'Sexually Transmitted Infections Screenings And Counseling',
#        'Tobacco Use Cessation Counseling',
#        'Welcome to Medicare Preventive Visit ', 'Therapeutic Shoes ',
#        'Orthotic Devices', 'Prosthetic Devices',
#        'Part B Coinsurance and Copayment', 'Respite Care',
#        'Occupational Therapy Home Health Agency',
#        'Occupational Therapy Outpatient Professional',
#        'Physical Therapy Home Health Agency',
#        'Physical Therapy Outpatient Professional',
#        'Pulmonary Rehabilitation', 'Speech Therapy Home Health Agency',
#        'Speech Therapy Outpatient Professional',
#        'Supervised Exercise Therapy ',
#        'Physical Therapy Outpatient Professional - Designated Care Program',
#        'Occupational Therapy Outpatient Professional - Designated Care Program',
#        'Speech Therapy Outpatient Professional - Designated Care Program',
#        'School Based Services', 'Self-Referral Services',
#        'SilverSneakers', 'Smoking Cessation Office Professional - PCP',
#        'Smoking Cessation Office Professional - Specialist',
#        'Smoking Cessation Office Professional - Preventive Services',
#        'Smoking Cessation Office Professional - Specialist - Designated Care Program',
#        'All Other Participating SNF - Days ',
#        'Preferred Participating SNF - Days ',
#        'Sterilization Ambulatory Surgical Center',
#        'Sterilization Inpatient Professional',
#        'Sterilization Observation Room Outpatient Institutional',
#        'Sterilization Office Professional - PCP',
#        'Sterilization Office Professional - Specialist',
#        'Sterilization Surgery Outpatient Institutional',
#        'Sterilization Office Professional - Specialist - Designated Care Program',
#        'Targeted Case Management Services', 'Telemonitoring',
#        'Air Ambulance', 'Ground Ambulance', 'Water Ambulance',
#        'Transportation - Supplemental',
#        'Transplants Inpatient Institutional - Hospital Days ',
#        'Transplants Inpatient Professional', 'Value Added Benefits',
#        'Vaccines for Children (VFC) Program ',
#        'Dilated Retinal Examination with a Visual',
#        'Remote Imaging For Detection Of Retinal Disease',
#        'Eyeglasses - Post Cataract Surgery',
#        'Glaucoma Screening - Preventive Care Services',
#        'Other Vision Services', 'Routine Eyewear - Supplemental',
#        'Routine Vision Exam - Supplemental',
#        'Eye Exam Office Professional - PCP',
#        'Eye Exam Office Professional - PCP - Designated Care Program',
#        'Glaucoma Screening - Preventive Care Services - Designated Care Program',
#        'Dilated Retinal Examination with a Visual - Designated Care Program',
#        'Remote Imaging For Detection Of Retinal Disease - Designated Care Program',
#        'Eyeglasses - Post Cataract Surgery - Designated Care Program',
#        'Eye Exam', 'Eye Exam - Designated Care Program',
#        'Visitor Travel - Supplemental', 'LiveHealth Online Services',
#        'Weight Reduction Program', 'Frail Elderly (FE)',
#        'Intellectual or Developmental Disabilities (IDD)',
#        'Work Opportunities Reward Kansans', 'Physical Disability (PD)',
#        'Serious Emotional Disturbance (SED)', 'Technology Assisted (TA)',
#        'Traumatic Brain Injuries (TBI)', 'Worldwide Emergency Care',
#        'Worldwide Urgent Care',
#        'Standard Retail Tier 1 Preferred Generic Drugs',
#        'Standard Retail Tier 2 Generic Drugs',
#        'Standard Retail Tier 3 Preferred Brand Drugs',
#        'Standard Retail Tier 4 Non-Preferred Brand Drugs',
#        'Standard Retail Tier 5 Specialty Tier Drugs',
#        'Standard Retail Tier 6 Select Care Drugs ',
#        'Preferred Retail Tier 1 Preferred Generic Drugs',
#        'Preferred Retail Tier 2 Generic Drugs',
#        'Preferred Retail Tier 3 Preferred Brand Drugs',
#        'Preferred Retail Tier 4 Non-Preferred Brand Drugs',
#        'Preferred Retail Tier 5 Specialty Tier Drugs',
#        'Preferred Retail Tier 6 Select Care Drugs ',
#        'Mail Order Tier 1 Preferred Generic Drugs',
#        'Mail Order Tier 2 Generic Drugs',
#        'Mail Order Tier 3 Preferred Brand Drugs',
#        'Mail Order Tier 4 Non-Preferred Brand Drugs',
#        'Mail Order Tier 5 Specialty Tier Drugs',
#        'Mail Order Tier 6 Select Care Drugs ',
#        'Exercise and Strength Training',
#        'Comprehensive Health Assessment', 'Non Opioid Pain Management',
#        'Nutritional Training and Consultation',
#        'Outreach Support Program', 'Over the Counter Supplemental ',
#        'Transitional Care', 'Healthy Pantry', 'Healthy Meals',
#        'Healthy Meals - EE', 'Healthy Pantry - EE',
#        'Healthy Food Deliveries'], dtype=object)

# %%
befitname_value = np.savetxt(r'train.txt', mapping_sheet['Benefit Name'].values, fmt='%s')

# %%
def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open('train.txt').read()))

def P(word, N=sum(WORDS.values())): 
    "Probability of `word`."
    return WORDS[word] / N

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %% [markdown]
# # Model Prediction

# %%
# Test Prediction COde
def inc_exc_prediction(benefit_name):
    import csv
    import json
#     benefit_name = correction(benefit_name)
#     sentence = mapping_sheet[mapping_sheet["Benefit Name"]==benefit_name]["Requirement Text"].iloc[0]
#     print(sentence)
    mapping_sheet_inclusions = []
    if str(mapping_sheet[mapping_sheet["Benefit Name"]==benefit_name]["Inclusions"].iloc[0])!="nan":
        mapping_sheet_inclusions = mapping_sheet[mapping_sheet["Benefit Name"]==benefit_name]["Inclusions"].iloc[0].split("\n")
        print(mapping_sheet_inclusions)
    mapping_sheet_exclusions = []
    if str(mapping_sheet[mapping_sheet["Benefit Name"]==benefit_name]["Exclusions"].iloc[0])!="nan":
        mapping_sheet_exclusions = mapping_sheet[mapping_sheet["Benefit Name"]==benefit_name]["Exclusions"].iloc[0].split("\n")
        print(mapping_sheet_exclusions)
    
#     df_new = df[df['requirement_text']==sentence] 
    #df_new = df[]
    getter = SentenceGetter(benefit_name)
    sentences = getter.sentences
    X = [sent2features(s) for s in sentences]
    y = [sent2labels(s) for s in sentences]
    predictions = crf1.predict(X)
    #print(predictions)
    predictions = crf1.predict(X)
    final_predictions = []
    for sentence_index,each_sentence_pred in enumerate(predictions):
        inc_string = ""
        exc_string = ""
        sentence_id = "sentence "+str(sentence_index)
        pattern = ""
        score = metrics.flat_accuracy_score([predictions[sentence_index]], [y[sentence_index]])
        f1_score =  metrics.flat_f1_score([predictions[sentence_index]], [y[sentence_index]], average='weighted', labels=new_classes)

        for word_index,each_iob in enumerate(each_sentence_pred):
            pattern = pattern+" "+str(X[sentence_index][word_index]['word.lower()'])
            if each_iob == "B_INCLUSION":
                inc_string = inc_string+","+str(X[sentence_index][word_index]['word.lower()'])
            elif each_iob == "I_INCLUSION":
                inc_string = inc_string+" "+str(X[sentence_index][word_index]['word.lower()'])
            elif each_iob == "B_EXCLUSION":
                exc_string = exc_string+","+str(X[sentence_index][word_index]['word.lower()'])
            elif each_iob == "I_EXCLUSION":
                exc_string = exc_string+" "+str(X[sentence_index][word_index]['word.lower()'])
        
        pred_inclusions = inc_string[1:].split(",")
        pred_inclusions = [i for i in pred_inclusions if i]
        for i in range(len(pred_inclusions)):
            for j in range(len(mapping_sheet_inclusions)):
                val = fuzz.ratio(pred_inclusions[i],mapping_sheet_inclusions[j])
                if val>80:
                    print(val)
                    pred_inclusions[i] = mapping_sheet_inclusions[j]
        
        pred_exclusions = exc_string[1:].split(",")
        pred_exclusions = [i for i in pred_exclusions if i]
        for i in range(len(pred_exclusions)):
            for j in range(len(mapping_sheet_exclusions)):
                val = fuzz.ratio(pred_exclusions[i],mapping_sheet_exclusions[j])
                if val>70:
                    print(val)
                    pred_exclusions[i] = mapping_sheet_exclusions[j]


        
        json_dict_pred = {}
        json_dict_pred["Inclusion"] = pred_inclusions
        json_dict_pred["Exclusion"] = pred_exclusions
        json_dict_pred["accuracy_score"] = score
        json_dict_pred["f1-score"] = f1_score

        if json_dict_pred["Inclusion"]!=[] or json_dict_pred["Exclusion"]!=[]:    
            json_dict_pred = json.dumps(json_dict_pred, sort_keys=True)
            final_predictions.append(json_dict_pred)

    return final_predictions

# %%
inc_exc_prediction("Dental Services - Designated Care Program")
# Out:
# ['Jaw Reconstruction', 'Oral Exams']
# ['Dental Care', 'Dental Treatment', 'Removal/Replacement Of Teeth ', 'Removal/Replacement Of Structures Directly Supporting Teeth', 'Dental Appliances', 'Dentures', 'Alveolar Process', 'Filings', 'Other dental devices', 'Dental plates']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-81fde7f6f257> in <module>
# ----> 1 inc_exc_prediction("Dental Services - Designated Care Program")
#
# <ipython-input-36-93213e5d7236> in inc_exc_prediction(benefit_name)
#      17 #     df_new = df[df['requirement_text']==sentence]
#      18     #df_new = df[]
# ---> 19     getter = SentenceGetter(benefit_name)
#      20     sentences = getter.sentences
#      21     X = [sent2features(s) for s in sentences]
#
# <ipython-input-21-08dc88d171c9> in __init__(self, data)
#      10                                                            s['POS'].values.tolist(),
#      11                                                            s['tags'].values.tolist())]
# ---> 12         self.grouped = self.data.groupby('sentence #').apply(agg_func)
#      13         self.sentences = [s for s in self.grouped]
#      14
#
# AttributeError: 'str' object has no attribute 'groupby'

# %%
inc_exc_prediction("Dental Services - Designated Care Program")
# Out:
# ['Jaw Reconstruction', 'Oral Exams']
# ['Dental Care', 'Dental Treatment', 'Removal/Replacement Of Teeth ', 'Removal/Replacement Of Structures Directly Supporting Teeth', 'Dental Appliances', 'Dentures', 'Alveolar Process', 'Filings', 'Other dental devices', 'Dental plates']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-81fde7f6f257> in <module>
# ----> 1 inc_exc_prediction("Dental Services - Designated Care Program")
#
# <ipython-input-36-93213e5d7236> in inc_exc_prediction(benefit_name)
#      17 #     df_new = df[df['requirement_text']==sentence]
#      18     #df_new = df[]
# ---> 19     getter = SentenceGetter(benefit_name)
#      20     sentences = getter.sentences
#      21     X = [sent2features(s) for s in sentences]
#
# <ipython-input-21-08dc88d171c9> in __init__(self, data)
#      10                                                            s['POS'].values.tolist(),
#      11                                                            s['tags'].values.tolist())]
# ---> 12         self.grouped = self.data.groupby('sentence #').apply(agg_func)
#      13         self.sentences = [s for s in self.grouped]
#      14
#
# AttributeError: 'str' object has no attribute 'groupby'

# %%
benefit_iface = gr.Interface(fn=inc_exc_prediction, inputs=gr.inputs.Textbox(default="Please enter the Benefit Text."), outputs="json")
benefit_iface.launch()
# Out:
# Running locally at: http://127.0.0.1:7860/
# To create a public link, set `share=True` in `launch()`.
# Interface loading below...
#         <iframe
#             width="1000"
#             height="500"
#             src="http://127.0.0.1:7860/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Tip: Add interpretation to your model by simply adding `interpretation="default"` to `Interface()`
# (<Flask 'gradio.networking'>, 'http://127.0.0.1:7860/', None)
# [2021-05-13 13:35:12,651] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\networking.py", line 133, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 272, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 246, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-36-93213e5d7236>", line 19, in inc_exc_prediction
#     getter = SentenceGetter(benefit_name)
#   File "<ipython-input-21-08dc88d171c9>", line 12, in __init__
#     self.grouped = self.data.groupby('sentence #').apply(agg_func)
# AttributeError: 'str' object has no attribute 'groupby'
# ['Jaw Reconstruction', 'Oral Exams']
# ['Dental Care', 'Dental Treatment', 'Removal/Replacement Of Teeth ', 'Removal/Replacement Of Structures Directly Supporting Teeth', 'Dental Appliances', 'Dentures', 'Alveolar Process', 'Filings', 'Other dental devices', 'Dental plates']
# [2021-05-13 13:35:13,792] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\networking.py", line 133, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 272, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 246, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-36-93213e5d7236>", line 19, in inc_exc_prediction
#     getter = SentenceGetter(benefit_name)
#   File "<ipython-input-21-08dc88d171c9>", line 12, in __init__
#     self.grouped = self.data.groupby('sentence #').apply(agg_func)
# AttributeError: 'str' object has no attribute 'groupby'
# ['Jaw Reconstruction', 'Oral Exams']
# ['Dental Care', 'Dental Treatment', 'Removal/Replacement Of Teeth ', 'Removal/Replacement Of Structures Directly Supporting Teeth', 'Dental Appliances', 'Dentures', 'Alveolar Process', 'Filings', 'Other dental devices', 'Dental plates']
# [2021-05-13 13:36:04,607] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\networking.py", line 133, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 272, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 246, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-36-93213e5d7236>", line 19, in inc_exc_prediction
#     getter = SentenceGetter(benefit_name)
#   File "<ipython-input-21-08dc88d171c9>", line 12, in __init__
#     self.grouped = self.data.groupby('sentence #').apply(agg_func)
# AttributeError: 'str' object has no attribute 'groupby'
# ['Jaw Reconstruction', 'Oral Exams']
# ['Dental Care', 'Dental Treatment', 'Removal/Replacement Of Teeth ', 'Removal/Replacement Of Structures Directly Supporting Teeth', 'Dental Appliances', 'Dentures', 'Alveolar Process', 'Filings', 'Other dental devices', 'Dental plates']
# [2021-05-13 13:36:05,520] ERROR in app: Exception on /api/predict/ [POST]
# Traceback (most recent call last):
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\networking.py", line 133, in predict
#     prediction, durations = app.interface.process(raw_input)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 272, in process
#     predictions, durations = self.run_prediction(processed_input, return_duration=True)
#   File "C:\Users\AG95028\AppData\Local\conda\conda\envs\myenv\lib\site-packages\gradio\interface.py", line 246, in run_prediction
#     prediction = predict_fn(*processed_input)
#   File "<ipython-input-36-93213e5d7236>", line 19, in inc_exc_prediction
#     getter = SentenceGetter(benefit_name)
#   File "<ipython-input-21-08dc88d171c9>", line 12, in __init__
#     self.grouped = self.data.groupby('sentence #').apply(agg_func)
# AttributeError: 'str' object has no attribute 'groupby'
# ['Jaw Reconstruction', 'Oral Exams']
# ['Dental Care', 'Dental Treatment', 'Removal/Replacement Of Teeth ', 'Removal/Replacement Of Structures Directly Supporting Teeth', 'Dental Appliances', 'Dentures', 'Alveolar Process', 'Filings', 'Other dental devices', 'Dental plates']
